# %% [markdown]
# # NAMs

# %%
import pandas as pd
import numpy as np

file_path = r"A:\Seismic_data_analysis\Seismic-Data-analysis\Data\NGAsub_MegaFlatfile_RotD50_050_R211022_public.xlsx"
df = pd.read_excel(file_path)

df.head()

cols = df.columns.to_list()
#print([col for col in cols if col.startswith("T")])
#print([col for col in cols if col.startswith("P")])
X_np = df[["Earthquake_Magnitude" , "Rjb_km" , "Vs30_Selected_for_Analysis_m_s" , "Fault_Type"]].to_numpy()
Y_np = df[["PGA_g" , "PGV_cm_sec" ] + [col for col in cols if col.startswith("T")] ].to_numpy()

print(X_np.shape , Y_np.shape)

mask = (X_np[: , 0 ] >= 4) & (X_np[: , 1] > 0) & (X_np[: , 1] < 500) & (X_np[: , 2] > 0) & (X_np[: , 3] >= 0) & (Y_np[: , 0] > 0) & (Y_np[: , 1] > 0)

X_np = X_np[mask]
Y_np = Y_np[mask]
#neg_val = Y_np[Y_np < 0]
#negative_values will be array([-2])

X_np[: , [2]] = np.log(X_np[:,[2]])

X_np = np.hstack((X_np , np.log(X_np[: , [1]])))
print(X_np.shape , Y_np.shape )
# Out:
# (71340, 4) (71340, 113)
# (54085, 5) (54085, 113)
